# %%
import random

# %%
distributions = {
    'alpha': {
        'a': 0.2,
        'b': 0.4,
        'c': 0.3,
        'd': 0.1,
    },
    'beta': {
        'a': 0.4,
        'b': 0.3,
        'c': 0.2,
        'd': 0.1,
    },
    'gamma': {
        'a': 0.1,
        'b': 0.2,
        'c': 0.3,
        'd': 0.4,
    },
    'delta': {
        'a': 0.1,
        'b': 0.3,
        'c': 0.4,
        'd': 0.2,
    }
}

player_type_distributions = {
    'alpha': 0.3,
    'beta': 0.4,
    'gamma': 0.1,
    'delta': 0.2,
}

# %%
def run_event(distribution):
    r = random.uniform(0,1)
    running_prob = 0
    for result, prob in distribution.iteritems():
        running_prob += prob
        if r < running_prob:
            return result


def play_game(player_type):
    return run_event(distributions[player_type])


def pick_random_player():
    return run_event(player_type_distributions)


def update_prior(prior, result, likelihood):
    
    unweighted_prior = {k: likelihood[k]*prior[k] for k in prior.keys()}
    
    return {
        k: v/sum(unweighted_prior.values())
        for k,v in unweighted_prior.iteritems()
    }

# %%
player_type = pick_random_player()
print player_type
prior = player_type_distributions
for i in range(100):
    result = play_game(player_type)
    likelihood = {k: v[result] for k, v in distributions.iteritems()}
    prior = update_prior(prior, result, likelihood)
print prior
# Out:
# beta
# {'alpha': 0.0034137934840486935, 'beta': 0.9965862064579402, 'gamma': 2.0698847244594902e-15, 'delta': 5.8008951976542603e-11}

# %%
opponents = {
    'w': {
        'a': 0.1,
        'b': 0.2,
        'c': 0.3,
        'd': 0.4,
    },
    'x': {
        'a': 0.3,
        'b': 0.2,
        'c': 0.1,
        'd': 0.4,
    },
    'y': {
        'a': 0.7,
        'b': 0.1,
        'c': 0.1,
        'd': 0.1,
    },
    'z': {
        'a': 0.4,
        'b': 0.3,
        'c': 0.2,
        'd': 0.1,
    },
}

opponent_distributions = {
    'w': 0.25,
    'x': 0.25,
    'y': 0.25,
    'z': 0.25,
}

# %%
player_type = pick_random_player()
print player_type
prior = player_type_distributions
for i in range(100):
    
    opponent = run_event(opponent_distributions) # 'w'
    opp_dist = opponents[opponent] # {'a': 0.1, ...}
    
    result = play_game(player_type) # 'a'
    
    player_dist = {k: v[result] for k,v in distributions.iteritems()}
    
    likelihood_player = {
        k: v*opp_dist[result] for k, v in player_dist.iteritems()
    }
    
    print i, result, opponent
    print opp_dist
    print {k: round(v/sum(likelihood_player.values()),2) for k,v in likelihood_player.iteritems()}
    
    prior = update_prior(prior, result, likelihood_player)
print prior
# Out:
# gamma
# 0 d x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 1 c x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 2 c y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 3 c w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 4 d y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 5 d z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 6 c z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 7 d w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 8 d w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 9 d y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 10 c y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 11 c w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 12 c z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 13 c y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 14 c z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 15 d x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 16 d w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 17 c w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 18 d x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 19 c x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 20 c x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 21 c y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 22 d x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 23 d x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 24 d z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 25 d w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 26 a y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.5, 'gamma': 0.13, 'delta': 0.13}
# 27 b y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.33, 'beta': 0.25, 'gamma': 0.17, 'delta': 0.25}
# 28 c w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 29 d x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 30 d x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 31 d z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 32 c y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 33 b w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.33, 'beta': 0.25, 'gamma': 0.17, 'delta': 0.25}
# 34 d y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 35 d y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 36 d x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 37 d w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 38 d x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 39 c w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 40 c z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 41 c w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 42 d y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 43 d w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 44 d x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 45 c y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 46 d w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 47 a y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.5, 'gamma': 0.13, 'delta': 0.13}
# 48 c y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 49 c w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 50 c y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 51 c x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 52 d z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 53 a w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.5, 'gamma': 0.13, 'delta': 0.13}
# 54 d y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 55 c x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 56 c y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 57 c x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 58 d z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 59 c w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 60 d w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 61 c y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 62 b y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.33, 'beta': 0.25, 'gamma': 0.17, 'delta': 0.25}
# 63 a y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.5, 'gamma': 0.13, 'delta': 0.13}
# 64 d y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 65 a z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.5, 'gamma': 0.13, 'delta': 0.13}
# 66 c z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 67 d y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 68 c y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 69 a y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.5, 'gamma': 0.13, 'delta': 0.13}
# 70 d w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 71 b x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.33, 'beta': 0.25, 'gamma': 0.17, 'delta': 0.25}
# 72 d z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 73 d w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 74 c w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 75 c w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 76 c w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 77 d z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 78 c x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 79 d x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 80 c z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 81 c y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 82 d z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 83 b z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.33, 'beta': 0.25, 'gamma': 0.17, 'delta': 0.25}
# 84 c x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 85 d w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 86 d w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 87 c y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 88 c z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 89 a z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.5, 'gamma': 0.13, 'delta': 0.13}
# 90 d z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 91 c x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 92 b y
# {'a': 0.7, 'c': 0.1, 'b': 0.1, 'd': 0.1}
# {'alpha': 0.33, 'beta': 0.25, 'gamma': 0.17, 'delta': 0.25}
# 93 c w
# {'a': 0.1, 'c': 0.3, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 94 a x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.5, 'gamma': 0.13, 'delta': 0.13}
# 95 c x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# 96 d x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.13, 'beta': 0.13, 'gamma': 0.5, 'delta': 0.25}
# 97 b x
# {'a': 0.3, 'c': 0.1, 'b': 0.2, 'd': 0.4}
# {'alpha': 0.33, 'beta': 0.25, 'gamma': 0.17, 'delta': 0.25}
# 98 a z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.5, 'gamma': 0.13, 'delta': 0.13}
# 99 c z
# {'a': 0.4, 'c': 0.2, 'b': 0.3, 'd': 0.1}
# {'alpha': 0.25, 'beta': 0.17, 'gamma': 0.25, 'delta': 0.33}
# {'alpha': 4.065743255109229e-20, 'beta': 9.927807603291579e-26, 'gamma': 0.9999963372854785, 'delta': 3.662714521418951e-06}
