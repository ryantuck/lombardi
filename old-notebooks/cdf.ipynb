# %% [markdown]
# # cumulative distributions
#
# Dicking around with CDFs.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import lombardi.data
import lombardi.stats
import lombardi.plot

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
x = np.linspace(0, 300, 1000)
metric = 'rushing_yds'

players = [
    'Todd Gurley',
    'Adrian Peterson',
    'Jamaal Charles',
    'LeSean McCoy',
    'Eddie Lacy',
    'Matt Forte',
    'DeMarco Murray',
    'LeGarrette Blount',
]

distributions = []
for player in players:
    data = lombardi.data.player_metric(player, metric)    
    distributions.append({
            'name': player,
            'pdf': lombardi.stats.fit_gamma(x, data, normalize=True)[1],
            'cdf': lombardi.stats.cdf(x, data)[1]
        })

# %%
def compare_players(player1, player2):
    f, axarr = plt.subplots(2, figsize=(20, 20))
    axarr[0].set_title('pdf', size=20)
    axarr[1].set_title('cdf', size=20)
    axarr[0].plot(x, player1['pdf'], label=player1['name'])
    axarr[0].plot(x, player2['pdf'], label=player2['name'])
    axarr[1].plot(x, player1['cdf'], label=player1['name'])
    axarr[1].plot(x, player2['cdf'], label=player2['name'])
    axarr[0].legend()
    axarr[1].legend()

# %%
compare_players(distributions[0], distributions[5])

# %%
def idx(yards):
    return int(float(yards) * (1000-1)/300)

# %%
def p(cdf, yds1, yds2):
    return cdf[idx(yds2)] - cdf[idx(yds1)]

# %%
p(distributions[5]['cdf'], 100, 150)
# Out:
# 0.17571397609231199

# %%
probs = []
for i in range(6):
    probs.append({
            player['name']: p(player['cdf'], i*50, 50*(i+1))
            for player in distributions
        })
df = pd.DataFrame(probs)

# %%
df
# Out:
#    Adrian Peterson  DeMarco Murray  Eddie Lacy  Jamaal Charles  \
# 0         0.179298        0.304063    0.271804        0.274842
# 1         0.400728        0.392296    0.469498        0.401290
# 2         0.276439        0.197904    0.201236        0.212952
# 3         0.104407        0.071064    0.028404        0.076299
# 4         0.026891        0.020975    0.001565        0.021762
# 5         0.005497        0.005611    0.000041        0.005509
#
#    LeGarrette Blount  LeSean McCoy  Matt Forte  Todd Gurley
# 0           0.541410      0.283965    0.314290     0.205969
# 1           0.317560      0.425799    0.461814     0.372540
# 2           0.099408      0.205868    0.175714     0.261261
# 3           0.026713      0.059436    0.038149     0.104190
# 4           0.006541      0.012549    0.006003     0.027912
# 5           0.001550      0.002219    0.000793     0.005767

# %%
data1 = lombardi.data.player_metric('DeMarco Murray', 'rushing_yds')
data1[36:53]
# Out:
# [51,
#  118,
#  167,
#  100,
#  149,
#  136,
#  115,
#  128,
#  141,
#  79,
#  100,
#  121,
#  73,
#  179,
#  81,
#  58,
#  100]

# %%
start_idx = 36
num_pts = 16
weights = np.linspace(1, 2, num_pts)

# %%
yds = data1[start_idx:start_idx + num_pts]
yds_weighted = lombardi.stats.weight_data(yds, weights)

print sorted(yds)
print sorted(yds_weighted)
# Out:
# [51, 58, 73, 79, 81, 100, 100, 115, 118, 121, 128, 136, 141, 149, 167, 179]
# [34, 78, 80, 84, 85, 88, 105, 108, 112, 122, 126, 127, 127, 141, 145, 225]

# %%
x = np.linspace(0, 300, 1000)
_, pdf = lombardi.stats.fit_gamma(x, yds)
_, pdf_norm = lombardi.stats.fit_gamma(x, yds_weighted)

# %%
figure = plt.figure(figsize=(20,10))
plt.plot(x, pdf, label='raw')
plt.plot(x, pdf_norm, label='weighted')
plt.legend()

# %%
figure = plt.figure(figsize=(20,10))
plt.plot(x, lombardi.stats.cdf(x, yds)[1], label='raw')
plt.plot(x, lombardi.stats.cdf(x, yds_weighted)[1], label='weighted')
plt.legend()

# %%
figure = plt.figure(figsize=(20,10))
plt.plot(range(16), sorted(yds), label='yds')
plt.plot(range(16), sorted(yds_weighted), label='weighted')

plt.legend()
# Out:
# 16

# %%
x = np.linspace(0, 300, 1000)
metric = 'receiving_yds'

rcv = [
    'Antonio Brown',
    'Odell Beckham',
    'Julio Jones',
]

rcvs = {p: {} for p in rcv}

for player in rcvs.keys():
    data = lombardi.data.player_metric(player, metric)    
    rcvs[player] = {
            'name': player,
            'pdf': lombardi.stats.fit_gamma(x, data, normalize=True)[1],
            'cdf': lombardi.stats.cdf(x, data)[1]
        }

# %%
compare_players(rcvs['Antonio Brown'], rcvs['Odell Beckham'])

# %%
x = np.linspace(0, 300, 1000)
metric = 'rushing_yds'

players = [
    'Todd Gurley',
    'C.J. Anderson',
]

rbs = {p: {} for p in players}

for player in rbs.keys():
    data = lombardi.data.player_metric(player, metric) 
    print player
    rbs[player] = {
            'name': player,
            'pdf': lombardi.stats.fit_gamma(x, data, normalize=True)[1],
            'cdf': lombardi.stats.cdf(x, data)[1]
        }
# Out:
# Todd Gurley
# C.J. Anderson

# %%
compare_players(rbs['C.J. Anderson'], rbs['Todd Gurley'])
