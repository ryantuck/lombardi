# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import lombardi

# %% [markdown]
# # player distributions
#
# This shows player histograms versus fits.

# %%
players = [
    ('Andrew Luck', 'passing_yds'),
    ('LeSean McCoy', 'rushing_yds'),
    ('Calvin Johnson', 'receiving_yds'),
]

for player in players:
    data = lombardi.data.player_metric(player[0], player[1], min_year=2014, max_year=2014)
    lombardi.plot.fit_demo(data, chart_title=player[0], normalize=True)

# %%
players = [
    'Antonio Brown',
    'Odell Beckham',
]

p = {p: lombardi.data.player_metric(p, 'receiving_yds') for p in players}
