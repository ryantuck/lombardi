# %%
import test
import lombardi.plot
# %matplotlib inline

# %%
reload(lombardi.plot)

players = [
    ('Tom Brady', 'passing_yds'),
    ('LeSean McCoy', 'rushing_yds'),
    ('Calvin Johnson', 'receiving_yds'),
]

for player in players:
    data = lombardi.plot.player_metric(player[0], player[1], min_year=None, max_year=None)
    lombardi.plot.fit_demo(data, chart_title=player[0])
# Out:
# 1000
# 1000
# 1000

# %%
reload(lombardi.plot)

players = [
    'Todd Gurley',
    'Adrian Peterson',
    'Jamaal Charles',
    'LeSean McCoy',
    'Eddie Lacy',
    'Matt Forte',
    'DeMarco Murray',
    'LeGarrette Blount',
]

x = np.linspace(0, 300, 1000)
plot = plt.figure(figsize=(20,10))
for player in players:
    data = lombardi.plot.player_metric(player=player, metric='rushing_yds')
    lombardi.plot.add_gamma_dist(data, x, label=player)
plt.legend()

# %%
reload(lombardi.plot)

players = [
    'Antonio Brown',
    'Dez Bryant',
    'T.Y. Hilton',
    'Jordan Matthews',
    'Michael Crabtree',
    'Vincent Jackson',
]

x = np.linspace(0, 300, 1000)
plot = plt.figure(figsize=(20,10))
for player in players:
    data = lombardi.plot.player_metric(player=player, metric='receiving_yds', min_year=2014)
    lombardi.plot.add_gamma_dist(data, x, label=player)
plt.legend()

# %%
reload(lombardi.plot)

players = [
    'Cam Newton',
    'Andrew Luck',
    'Kirk Cousins',
    'Jameis Winston',
    'Joe Flacco',
]

x = np.linspace(0, 600, 1000)
plot = plt.figure(figsize=(20,10))
for player in players:
    data = lombardi.plot.player_metric(player=player, metric='passing_yds', min_year=2014)
    lombardi.plot.add_gamma_dist(data, x, label=player)
plt.legend()
